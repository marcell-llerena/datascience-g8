# %%
## CONCATENADO

import pandas as pd

enero = pd.DataFrame({
    "mes": ["Enero"],
    "num_mes": [1]
})

febrero = pd.DataFrame({
    "mes": ["Febrero"],
    "num_mes": [2]
})

marzo = pd.DataFrame({
    "mes": ["Marzo"],
    "num_mes": [3]
})

# %%
pd.concat([enero, febrero, marzo], axis=1)
# Out:
#      mes  num_mes      mes  num_mes    mes  num_mes
# 0  Enero        1  Febrero        2  Marzo        3

# %%
pd.concat([enero, febrero, marzo], axis=0)
# Out:
#        mes  num_mes
# 0    Enero        1
# 0  Febrero        2
# 0    Marzo        3

# %% [markdown]
# ### JOINS

# %%
import pandas as pd

ventas = pd.read_csv(
    "/Users/marcell/Documents/codigo_by_tecsup/datascience-g8/data/ventas.csv"
)

catalogo_prods = pd.read_csv(
    "/Users/marcell/Documents/codigo_by_tecsup/datascience-g8/data/catalogo_productos.csv"
)

# %%
ventas.head(3)
# Out:
#         fecha  region     vendedor     producto   categoria  unidades  \
# 0  2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 1  2024-01-02     Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 2  2024-01-02  Centro  Carlos Vega   Silla Ergo  Mobiliario         1
#
#    precio_unitario  descuento
# 0              130        0.0
# 1              320        0.0
# 2              280        0.0

# %%
ventas.shape
# Out:
# (1200, 8)

# %%
catalogo_prods.head(3)
# Out:
#       producto  coste_unitario proveedor  stock
# 0   Laptop Pro             780  TecnoSur     45
# 1   Monitor 27             195  TecnoSur    120
# 2  Teclado Mec              52   InputCo    300

# %%
left_join = ventas.merge(catalogo_prods, on="producto", how="left")
left_join
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 0     2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 1     2024-01-02     Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 2     2024-01-02  Centro  Carlos Vega   Silla Ergo  Mobiliario         1
# 3     2024-01-02  Centro   Pedro Diaz   Laptop Pro  Tecnologia        10
# 4     2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# ...          ...     ...          ...          ...         ...       ...
# 1195  2024-12-30    Este   Luis Gomez   Raton Ergo  Accesorios         4
# 1196  2024-12-30    Este   Marta Ruiz   Laptop Pro  Tecnologia        13
# 1197  2024-12-31   Oeste   Ana Torres   Monitor 27  Tecnologia         2
# 1198  2024-12-31   Norte   Ana Torres   Monitor 27  Tecnologia         6
# 1199  2024-12-31   Norte   Marta Ruiz   Raton Ergo  Accesorios         8
#
#       precio_unitario  descuento  coste_unitario proveedor  stock
# ...

# %%
left_join.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fecha            1200 non-null   str
#  1   region           1200 non-null   str
#  2   vendedor         1182 non-null   str
#  3   producto         1200 non-null   str
#  4   categoria        1200 non-null   str
#  5   unidades         1200 non-null   int64
#  6   precio_unitario  1200 non-null   int64
#  7   descuento        1165 non-null   float64
#  8   coste_unitario   1200 non-null   int64
#  9   proveedor        1200 non-null   str
#  10  stock            1200 non-null   int64
# dtypes: float64(1), int64(4), str(6)
# memory usage: 103.3 KB

# %%
ventas.loc[1199, "producto"] = "Fuente de poder"
ventas.tail(5)
# Out:
#            fecha region    vendedor         producto   categoria  unidades  \
# 1195  2024-12-30   Este  Luis Gomez       Raton Ergo  Accesorios         4
# 1196  2024-12-30   Este  Marta Ruiz       Laptop Pro  Tecnologia        13
# 1197  2024-12-31  Oeste  Ana Torres       Monitor 27  Tecnologia         2
# 1198  2024-12-31  Norte  Ana Torres       Monitor 27  Tecnologia         6
# 1199  2024-12-31  Norte  Marta Ruiz  Fuente de poder  Accesorios         8
#
#       precio_unitario  descuento
# 1195               45       0.00
# 1196             1200       0.05
# 1197              320       0.05
# 1198              320       0.00
# 1199               45       0.00

# %%
left_join = ventas.merge(catalogo_prods, on="producto", how="left")
left_join
# Out:
#            fecha  region     vendedor         producto   categoria  unidades  \
# 0     2024-01-02   Oeste   Pedro Diaz      Auriculares  Accesorios         5
# 1     2024-01-02     Sur   Luis Gomez       Monitor 27  Tecnologia        14
# 2     2024-01-02  Centro  Carlos Vega       Silla Ergo  Mobiliario         1
# 3     2024-01-02  Centro   Pedro Diaz       Laptop Pro  Tecnologia        10
# 4     2024-01-03     Sur   Elena Mora      Auriculares  Accesorios         2
# ...          ...     ...          ...              ...         ...       ...
# 1195  2024-12-30    Este   Luis Gomez       Raton Ergo  Accesorios         4
# 1196  2024-12-30    Este   Marta Ruiz       Laptop Pro  Tecnologia        13
# 1197  2024-12-31   Oeste   Ana Torres       Monitor 27  Tecnologia         2
# 1198  2024-12-31   Norte   Ana Torres       Monitor 27  Tecnologia         6
# 1199  2024-12-31   Norte   Marta Ruiz  Fuente de poder  Accesorios         8
#
# ...

# %%
inner_join = ventas.merge(catalogo_prods, on="producto", how="inner")
inner_join
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 0     2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 1     2024-01-02     Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 2     2024-01-02  Centro  Carlos Vega   Silla Ergo  Mobiliario         1
# 3     2024-01-02  Centro   Pedro Diaz   Laptop Pro  Tecnologia        10
# 4     2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# ...          ...     ...          ...          ...         ...       ...
# 1194  2024-12-30   Norte   Ana Torres   Tablet Air  Tecnologia         4
# 1195  2024-12-30    Este   Luis Gomez   Raton Ergo  Accesorios         4
# 1196  2024-12-30    Este   Marta Ruiz   Laptop Pro  Tecnologia        13
# 1197  2024-12-31   Oeste   Ana Torres   Monitor 27  Tecnologia         2
# 1198  2024-12-31   Norte   Ana Torres   Monitor 27  Tecnologia         6
#
#       precio_unitario  descuento  coste_unitario proveedor  stock
# ...

# %%
# inner_join = ventas.merge(catalogo_prods, on="producto", how="")
