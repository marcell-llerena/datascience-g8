# %% [markdown]
# ### Input
#
# - Captura valores por teclado en string

# %%
nombre = input("Ingresa tu nombre")
print(f"Tu nombre es: {nombre}")
# Out:
# Tu nombre es:

# %%
edad = input("Ingresa tu edad")
print(f"Tu edad es: {edad}")
# Out:
# Tu edad es:

# %%
print(type(edad))
# Out:
# <class 'str'>

# %%
edad + "5"
# Out:
# '5'

# %%
int(edad) + 5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 int(edad) + 5
#
# ValueError: invalid literal for int() with base 10: ''

# %%
edad = "mil"
int(edad)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 edad = "mil"
# ----> 2 int(edad)
#
# ValueError: invalid literal for int() with base 10: 'mil'

# %%
edad = 1000
str(edad)
# Out:
# '1000'
