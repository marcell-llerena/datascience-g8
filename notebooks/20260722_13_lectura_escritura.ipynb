# %% [markdown]
# ### Escritura de archivos modo (write / append)

# %%
with open("../data/notas.txt", "w") as f:
    f.write("Primera linea\n")
    f.write("Segunda linea\n")

with open("../data/notas.txt", "w") as f:
    f.write("Tercera linea\n")

# %%
with open("../data/notas.txt", "w") as f:
    f.write("Primera linea\n")
    f.write("Segunda linea\n")

with open("../data/notas.txt", "a") as f:
    f.write("Tercera linea\n")

# %% [markdown]
# ### Lectura de archivos (read)

# %%
with open("../data/notas.txt", "r") as f:
    contenido = f.read()
    print(contenido)
# Out:
# Primera linea
# Segunda linea
# Tercera linea

# %%
len(contenido)
# Out:
# 42

# %%
# for linea in contenido:
#     print(linea)

# %%
with open("../data/notas.txt", "r") as f:
    contenido = f.readlines()
    print(contenido)

for linea in contenido:
    print(linea)
# Out:
# ['Primera linea\n', 'Segunda linea\n', 'Tercera linea\n']
# Primera linea
#
# Segunda linea
#
# Tercera linea

# %%
len(contenido)
# Out:
# 3
