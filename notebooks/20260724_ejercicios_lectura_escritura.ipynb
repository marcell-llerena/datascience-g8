# %%
def extract_contenido(ruta: str) -> list[str]:
    mi_lista = []
    with open(ruta, "r") as f:
        contenido = f.read()
        lineas = contenido.split("\n")
        for linea in lineas:
            if "registro" in linea.lower():
                continue

            if not linea:
                continue

            if "instrucciones" in linea.lower():
                break

            mi_lista.append(linea)

    return mi_lista


contenido = extract_contenido(
    # "/Users/marcell/Documents/codigo_by_tecsup/datascience-g8/data/estudiantes_python.txt"
    "../data/estudiantes_python.txt"
)

# %%
contenido
# Out:
# ['V001, Polo Oversize Anime, M, Negro, Valeria Rojas, Arequipa, 2, 45.00, Yape, entregado',
#  'V002, Polo Streetwear Retro, L, Blanco, Diego Salazar, Arequipa, 1, 50.00, Efectivo, pendiente',
#  'V003, Polo Minimalista Logo, S, Gris, Camila Herrera, Cusco, 3, 38.00, Plin, entregado',
#  'V004, Polo Urbano 90s, M, Azul, Luis Ramos, Lima, 1, 55.00, Tarjeta, cancelado',
#  'V005, Polo Oversize Anime, XL, Negro, Andrea Torres, Arequipa, 2, 45.00, Yape, entregado',
#  'V006, Polo Gamer Edition, L, Rojo, Carlos Medina, Puno, 1, 48.00, Efectivo, pendiente',
#  'V007, Polo Streetwear Retro, M, Blanco, Sofía Vargas, Arequipa, 4, 50.00, Plin, entregado',
#  'V008, Polo Minimalista Logo, M, Verde, Jorge Flores, Tacna, 2, 38.00, Yape, entregado',
#  'V009, Polo Gamer Edition, S, Negro, María Quispe, Arequipa, 1, 48.00, Tarjeta, pendiente',
#  'V010, Polo Urbano 90s, L, Azul, Andrés Castillo, Cusco, 2, 55.00, Efectivo, entregado',
#  'V011, Polo Oversize Anime, M, Morado, Lucía Vargas, Arequipa, 1, 45.00, Yape, entregado',
#  'V012, Polo Streetwear Retro, XL, Blanco, Pedro Huamán, Lima, 2, 50.00, Plin, pendiente',
#  'V013, Polo Minimalista Logo, L, Gris, Gabriela Núñez, Arequipa, 5, 38.00, Tarjeta, entregado',
#  'V014, Polo Gamer Edition, M, Negro, Renato Paredes, Tacna, 2, 48.00, Yape, cancelado',
#  'V015, Polo Urbano 90s, S, Azul, Fernanda López, Arequipa, 3, 55.00, Efectivo, entregado']

# %%
class Estudiante:
    def __init__(
        self,
        nombre: str,
        edad: int,
        ciudad: str,
        nota: float
    ) -> None:
        self.nombre = nombre
        self.edad = edad
        self.ciudad = ciudad
        self.nota = nota


class Aula:
    def __init__(
        self,
        estudiantes: list[str]
    ) -> None:
        self.estudiantes: list[Estudiante] = []

        for estudiante in estudiantes:
            info = [item.strip() for item in estudiante.split(",")]
            estudiante = Estudiante(
                nombre=info[0],
                edad=int(info[1]),
                ciudad=info[2],
                nota=float(info[3])
            )
            self.estudiantes.append(estudiante)

    def __len__(self) -> int:
        return len(self.estudiantes)

    def filtro_por_ciudad(self, ciudad: str) -> None:
        for estudiante in self.estudiantes:
            if estudiante.ciudad.lower() == ciudad:
                print(estudiante.nombre)

    def get_aprobados(self, min_nota: int = 13) -> list[str]:
        estudiantes = []
        for estudiante in self.estudiantes:
            if estudiante.nota >= min_nota:
                estudiantes.append(estudiante.nombre)

        return estudiantes

    def get_num_aprobados(self, min_nota: int = 13) -> int:
        return len(self.get_aprobados(min_nota))

    def export_alumnos(self, ruta: str) -> None:
        with open(ruta, "w") as f:
            f.write("nombre, edad, ciudad, nota\n")

        for estudiante in self.estudiantes:
            with open(ruta, "a") as f:
                f.write(f"{estudiante.nombre}, {estudiante.edad}, {estudiante.ciudad}, {estudiante.nota}\n")

aula = Aula(contenido)

# %%
aula.export_alumnos("../data/alumnos.csv")

# %%
aula.filtro_por_ciudad("cusco")
# Out:
# María Quispe
# Andrés Castillo

# %%
aula.get_aprobados(min_nota=15)
# Out:
# ['Ana Torres',
#  'María Quispe',
#  'Sofía Vargas',
#  'Valeria Rojas',
#  'Camila Herrera']

# %%
aula.get_num_aprobados(min_nota=15)
# Out:
# 5

# %%
contenido
# Out:
# ['Ana Torres, 18, Arequipa, 16.5',
#  'Luis Ramos, 21, Lima, 14.0',
#  'María Quispe, 19, Cusco, 18.2',
#  'Carlos Medina, 22, Arequipa, 11.8',
#  'Sofía Vargas, 20, Trujillo, 17.4',
#  'Diego Salazar, 18, Puno, 13.6',
#  'Valeria Rojas, 23, Lima, 19.0',
#  'Jorge Flores, 21, Tacna, 12.5',
#  'Camila Herrera, 19, Arequipa, 15.7',
#  'Andrés Castillo, 20, Cusco, 10.9']
