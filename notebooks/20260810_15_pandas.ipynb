# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.5

# %% [markdown]
# ### SERIES

# %%
s = pd.Series([120, 85, 200, 45],
              index=["ene", "feb", "mar", "abr"],
              name="ventas")

print(s["mar"])       # acceso por etiqueta
# Out:
# 200

# %%
print(s["abr"])
# Out:
# 45

# %%
print(s * 1.21)       # vectorizado: IVA
# Out:
# ene    145.20
# feb    102.85
# mar    242.00
# abr     54.45
# Name: ventas, dtype: float64

# %%
s.mean()
# Out:
# np.float64(112.5)

# %%
s.max()
# Out:
# np.int64(200)

# %% [markdown]
# ### DATAFRAME

# %%
import numpy as np

# %%
# a) Desde un diccionario de listas (la más habitual)
df = pd.DataFrame(
    {
        "producto": ["Laptop", "Monitor", "Teclado"],
        "unidades": [3, 7, 12],
        "precio":   [1200.0, 320.0, 95.0],
    }
)

print(df)
# Out:
#   producto  unidades  precio
# 0   Laptop         3  1200.0
# 1  Monitor         7   320.0
# 2  Teclado        12    95.0

# %%
df.head()
# Out:
#   producto  unidades  precio
# 0   Laptop         3  1200.0
# 1  Monitor         7   320.0
# 2  Teclado        12    95.0

# %%
# b) Desde una lista de diccionarios (típico de una API JSON)
df2 = pd.DataFrame(
    [
        {"producto": "Laptop", "unidades": 3},
        {"producto": "Monitor", "unidades": 7}
    ]
)

df2.head()
# Out:
#   producto  unidades
# 0   Laptop         3
# 1  Monitor         7

# %%
# c) Desde una lista de listas, indicando las columnas
df3 = pd.DataFrame(
    [
        ["Laptop", 3],
        ["Monitor", 7]
    ],
    columns=["producto", "unidades"]
)

df3.head()
# Out:
#   producto  unidades
# 0   Laptop         3
# 1  Monitor         7

# %%
# d) Desde un array de NumPy
df4 = pd.DataFrame(np.random.rand(3, 2), columns=["x", "y"])
df4.head()
# Out:
#           x         y
# 0  0.126059  0.475424
# 1  0.274851  0.610335
# 2  0.897882  0.782234

# %% [markdown]
# ### CREACION DE COLUMNS

# %%
df
# Out:
#   producto  unidades  precio
# 0   Laptop         3  1200.0
# 1  Monitor         7   320.0
# 2  Teclado        12    95.0

# %%
df.shape
# Out:
# (3, 3)

# %%
df["importe"] = df["unidades"] * df["precio"]

print(df.shape)
# Out:
# (3, 4)

# %%
df.columns
# Out:
# Index(['producto', 'unidades', 'precio', 'importe'], dtype='str')

# %%
print(df.columns.tolist())
# Out:
# ['producto', 'unidades', 'precio', 'importe']

# %%
df.head()
# Out:
#   producto  unidades  precio  importe
# 0   Laptop         3  1200.0   3600.0
# 1  Monitor         7   320.0   2240.0
# 2  Teclado        12    95.0   1140.0

# %%
df["dummy"] = 6

df.head()
# Out:
#   producto  unidades  precio  importe  dummy
# 0   Laptop         3  1200.0   3600.0      6
# 1  Monitor         7   320.0   2240.0      6
# 2  Teclado        12    95.0   1140.0      6

# %%
df["dummy2"] = [5, 4, 1]

df.head()
# Out:
#   producto  unidades  precio  importe  dummy  dummy2
# 0   Laptop         3  1200.0   3600.0      6       5
# 1  Monitor         7   320.0   2240.0      6       4
# 2  Teclado        12    95.0   1140.0      6       1

# %%
# Crea una Series con las temperaturas [21, 24, 19, 27, 30] e índice de lunes a viernes.
temperaturas = pd.Series(
    [21, 24, 19, 27, 30],
    index=["Lunes", "Martes", "Miercoles", "Jueves", "Viernes"]
)

print(temperaturas)

# Muestra la media, el máximo y el día que corresponde al máximo (usa .idxmax()).
print("-"*100)
print("Media: ", temperaturas.mean())
print("Maximo: ", temperaturas.max())
print("Dia maximo: ", temperaturas.idxmax())
print("Dia maximo indice: ", temperaturas.argmax())
print("-"*100)

# Crea un DataFrame con 5 productos: nombre, categoría, stock y precio (inventados).
df = pd.DataFrame(
    {
        "nombre": ["Laptop", "Monitor", "Teclado", "Mouse", "Fuente de poder"],
        "categoria": ["Tecnologia", "Tecnologia", "Tecnologia", "Tecnologia", "Tecnologia"],
        "stock": [3, 7, 12, 1, 0],
        "precio":   [1200.0, 320.0, 95.0, 12.23, 90.8]
    }
)
df.head()

# Añade una columna valor_stock = stock × precio.
df["valor_stock"] = df["stock"] * df["precio"]
df.head()

# Imprime la forma del DataFrame y la lista de nombres de columna.
print(df.shape)

print(df.columns.to_list())
# Out:
# Lunes        21
# Martes       24
# Miercoles    19
# Jueves       27
# Viernes      30
# dtype: int64
# ----------------------------------------------------------------------------------------------------
# Media:  24.2
# Maximo:  30
# Dia maximo:  Viernes
# Dia maximo indice:  4
# ----------------------------------------------------------------------------------------------------
# (5, 5)
# ['nombre', 'categoria', 'stock', 'precio', 'valor_stock']

# %%
df.head(2)
# Out:
#         fecha region    vendedor     producto   categoria  unidades  \
# 0  2024-01-02  Oeste  Pedro Diaz  Auriculares  Accesorios         5
# 1  2024-01-02    Sur  Luis Gomez   Monitor 27  Tecnologia        14
#
#    precio_unitario  descuento
# 0              130        0.0
# 1              320        0.0

# %%
temperaturas.head()
# Out:
# Lunes        21
# Martes       24
# Miercoles    19
# Jueves       27
# Viernes      30
# dtype: int64

# %% [markdown]
# ### Read CSV

# %%
import pandas as pd


tablas = pd.read_html("https://gist.github.com/netj/8836201")
tablas[0].head()
# Out:
#    Unnamed: 0  sepal.length  sepal.width  petal.length  petal.width variety
# 0         NaN           5.1          3.5           1.4          0.2  Setosa
# 1         NaN           4.9          3.0           1.4          0.2  Setosa
# 2         NaN           4.7          3.2           1.3          0.2  Setosa
# 3         NaN           4.6          3.1           1.5          0.2  Setosa
# 4         NaN           5.0          3.6           1.4          0.2  Setosa

# %%
# /Users/marcell/Documents/codigo_by_tecsup/datascience-g8/data/ventas.csv
df = pd.read_csv(
    "/Users/marcell/Documents/codigo_by_tecsup/datascience-g8/data/ventas.csv",
    dtype={"precio_unitario": "float64"}
)
# Out:
#         fecha  region     vendedor     producto   categoria  unidades  \
# 0  2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 1  2024-01-02     Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 2  2024-01-02  Centro  Carlos Vega   Silla Ergo  Mobiliario         1
# 3  2024-01-02  Centro   Pedro Diaz   Laptop Pro  Tecnologia        10
# 4  2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# 5  2024-01-03   Oeste  Javier Sanz   Escritorio  Mobiliario         2
# 6  2024-01-03   Norte  Carlos Vega   Silla Ergo  Mobiliario         4
# 7  2024-01-03   Norte   Sofia Leon   Silla Ergo  Mobiliario         1
# 8  2024-01-03  Centro  Carlos Vega   Laptop Pro  Tecnologia         1
# 9  2024-01-03  Centro   Pedro Diaz   Escritorio  Mobiliario         2
#
#    precio_unitario  descuento
# 0            130.0        0.0
# 1            320.0        0.0
# 2            280.0        0.0
# 3           1200.0        0.0
# 4            130.0        0.1
# ...

# %% [markdown]
# ### Explorar data rápidamente

# %%
df.head(n=10)

# %%
df.tail(5)
# Out:
#            fecha region    vendedor    producto   categoria  unidades  \
# 1195  2024-12-30   Este  Luis Gomez  Raton Ergo  Accesorios         4
# 1196  2024-12-30   Este  Marta Ruiz  Laptop Pro  Tecnologia        13
# 1197  2024-12-31  Oeste  Ana Torres  Monitor 27  Tecnologia         2
# 1198  2024-12-31  Norte  Ana Torres  Monitor 27  Tecnologia         6
# 1199  2024-12-31  Norte  Marta Ruiz  Raton Ergo  Accesorios         8
#
#       precio_unitario  descuento
# 1195               45       0.00
# 1196             1200       0.05
# 1197              320       0.05
# 1198              320       0.00
# 1199               45       0.00

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fecha            1200 non-null   str
#  1   region           1200 non-null   str
#  2   vendedor         1182 non-null   str
#  3   producto         1200 non-null   str
#  4   categoria        1200 non-null   str
#  5   unidades         1200 non-null   int64
#  6   precio_unitario  1200 non-null   int64
#  7   descuento        1165 non-null   float64
# dtypes: float64(1), int64(2), str(5)
# memory usage: 75.1 KB

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fecha            1200 non-null   str
#  1   region           1200 non-null   str
#  2   vendedor         1182 non-null   str
#  3   producto         1200 non-null   str
#  4   categoria        1200 non-null   str
#  5   unidades         1200 non-null   int64
#  6   precio_unitario  1200 non-null   float64
#  7   descuento        1165 non-null   float64
# dtypes: float64(2), int64(1), str(5)
# memory usage: 75.1 KB

# %%
df.describe()
# Out:
#           unidades  precio_unitario    descuento
# count  1200.000000      1200.000000  1165.000000
# mean      7.275833       387.412500     0.047639
# std       4.054024       346.020316     0.056273
# min       1.000000        45.000000     0.000000
# 25%       4.000000       130.000000     0.000000
# 50%       7.000000       280.000000     0.000000
# 75%      11.000000       450.000000     0.100000
# max      14.000000      1200.000000     0.150000

# %%
df.sample(10)
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 215   2024-03-02    Este   Luis Gomez   Laptop Pro  Tecnologia         8
# 164   2024-02-19    Este   Luis Gomez   Silla Ergo  Mobiliario         5
# 724   2024-08-11  Centro  Carlos Vega   Laptop Pro  Tecnologia        11
# 589   2024-07-02    Este  Javier Sanz   Silla Ergo  Mobiliario         4
# 971   2024-10-21     Sur   Pedro Diaz  Auriculares  Accesorios         9
# 648   2024-07-18  Centro   Elena Mora   Tablet Air  Tecnologia         8
# 755   2024-08-20     Sur   Sofia Leon   Raton Ergo  Accesorios         5
# 419   2024-05-14    Este   Luis Gomez   Raton Ergo  Accesorios         4
# 1047  2024-11-09  Centro   Luis Gomez  Auriculares  Accesorios         9
# 835   2024-09-14  Centro   Marta Ruiz   Escritorio  Mobiliario        13
#
#       precio_unitario  descuento
# 215            1200.0       0.00
# 164             280.0       0.10
# 724            1200.0       0.00
# ...

# %%
df.describe(include="object")
# Out:
# /var/folders/y4/wh20svfj197816v0mh0mncwh0000gn/T/ipykernel_65502/702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#              fecha region    vendedor    producto   categoria
# count         1200   1200        1182        1200        1200
# unique         349      5           8           8           3
# top     2024-02-21  Norte  Marta Ruiz  Silla Ergo  Tecnologia
# freq             9    305         170         177         447

# %%
df["region"].unique()
# Out:
# <StringArray>
# ['Oeste', 'Sur', 'Centro', 'Norte', 'Este']
# Length: 5, dtype: str

# %%
df["region"].nunique()
# Out:
# 5

# %%
df["region"].value_counts()
# Out:
# region
# Norte     305
# Centro    272
# Sur       240
# Oeste     203
# Este      180
# Name: count, dtype: int64

# %%
df["producto"].value_counts()
# Out:
# producto
# Silla Ergo     177
# Monitor 27     159
# Auriculares    158
# Tablet Air     149
# Raton Ergo     146
# Laptop Pro     139
# Escritorio     139
# Teclado Mec    133
# Name: count, dtype: int64

# %%
df["producto"].mode()
# Out:
# 0    Silla Ergo
# Name: producto, dtype: str

# %% [markdown]
# ### Seleccionar columnar

# %%
df["producto"]
# Out:
# 0       Auriculares
# 1        Monitor 27
# 2        Silla Ergo
# 3        Laptop Pro
# 4       Auriculares
#            ...
# 1195     Raton Ergo
# 1196     Laptop Pro
# 1197     Monitor 27
# 1198     Monitor 27
# 1199     Raton Ergo
# Name: producto, Length: 1200, dtype: str

# %%
df[["fecha", "region", "unidades"]]
# Out:
#            fecha  region  unidades
# 0     2024-01-02   Oeste         5
# 1     2024-01-02     Sur        14
# 2     2024-01-02  Centro         1
# 3     2024-01-02  Centro        10
# 4     2024-01-03     Sur         2
# ...          ...     ...       ...
# 1195  2024-12-30    Este         4
# 1196  2024-12-30    Este        13
# 1197  2024-12-31   Oeste         2
# 1198  2024-12-31   Norte         6
# 1199  2024-12-31   Norte         8
#
# [1200 rows x 3 columns]

# %%
df.head(2)
# Out:
#         fecha region    vendedor     producto   categoria  unidades  \
# 0  2024-01-02  Oeste  Pedro Diaz  Auriculares  Accesorios         5
# 1  2024-01-02    Sur  Luis Gomez   Monitor 27  Tecnologia        14
#
#    precio_unitario  descuento
# 0            130.0        0.0
# 1            320.0        0.0

# %%
df.loc[0: 4]
# Out:
#         fecha  region     vendedor     producto   categoria  unidades  \
# 0  2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 1  2024-01-02     Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 2  2024-01-02  Centro  Carlos Vega   Silla Ergo  Mobiliario         1
# 3  2024-01-02  Centro   Pedro Diaz   Laptop Pro  Tecnologia        10
# 4  2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
#
#    precio_unitario  descuento
# 0            130.0        0.0
# 1            320.0        0.0
# 2            280.0        0.0
# 3           1200.0        0.0
# 4            130.0        0.1

# %%
df.loc[1190:1199, ["producto", "unidades"]]
# Out:
#          producto  unidades
# 1190   Laptop Pro         1
# 1191   Silla Ergo         3
# 1192  Teclado Mec         8
# 1193   Raton Ergo         7
# 1194   Tablet Air         4
# 1195   Raton Ergo         4
# 1196   Laptop Pro        13
# 1197   Monitor 27         2
# 1198   Monitor 27         6
# 1199   Raton Ergo         8

# %%
df.loc[:,  ["producto", "unidades"]]
# Out:
#          producto  unidades
# 0     Auriculares         5
# 1      Monitor 27        14
# 2      Silla Ergo         1
# 3      Laptop Pro        10
# 4     Auriculares         2
# ...           ...       ...
# 1195   Raton Ergo         4
# 1196   Laptop Pro        13
# 1197   Monitor 27         2
# 1198   Monitor 27         6
# 1199   Raton Ergo         8
#
# [1200 rows x 2 columns]

# %%
df.tail()
# Out:
#            fecha region    vendedor    producto   categoria  unidades  \
# 1195  2024-12-30   Este  Luis Gomez  Raton Ergo  Accesorios         4
# 1196  2024-12-30   Este  Marta Ruiz  Laptop Pro  Tecnologia        13
# 1197  2024-12-31  Oeste  Ana Torres  Monitor 27  Tecnologia         2
# 1198  2024-12-31  Norte  Ana Torres  Monitor 27  Tecnologia         6
# 1199  2024-12-31  Norte  Marta Ruiz  Raton Ergo  Accesorios         8
#
#       precio_unitario  descuento
# 1195             45.0       0.00
# 1196           1200.0       0.05
# 1197            320.0       0.05
# 1198            320.0       0.00
# 1199             45.0       0.00

# %%
df.iloc[-5:, [3, 5]]
# Out:
#         producto  unidades
# 1195  Raton Ergo         4
# 1196  Laptop Pro        13
# 1197  Monitor 27         2
# 1198  Monitor 27         6
# 1199  Raton Ergo         8

# %% [markdown]
# ### Ordenar dataframe

# %%
df.sort_values("unidades", ascending=True)
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 317   2024-04-10     Sur   Elena Mora  Teclado Mec  Accesorios         1
# 679   2024-07-28   Norte   Luis Gomez   Monitor 27  Tecnologia         1
# 673   2024-07-25     Sur  Carlos Vega   Laptop Pro  Tecnologia         1
# 670   2024-07-25   Oeste   Elena Mora  Auriculares  Accesorios         1
# 816   2024-09-08  Centro   Sofia Leon   Silla Ergo  Mobiliario         1
# ...          ...     ...          ...          ...         ...       ...
# 1117  2024-12-06   Norte   Pedro Diaz   Monitor 27  Tecnologia        14
# 321   2024-04-11     Sur  Javier Sanz   Raton Ergo  Accesorios        14
# 326   2024-04-12   Norte   Luis Gomez   Escritorio  Mobiliario        14
# 1130  2024-12-09     Sur   Pedro Diaz  Teclado Mec  Accesorios        14
# 972   2024-10-21   Oeste  Carlos Vega   Silla Ergo  Mobiliario        14
#
#       precio_unitario  descuento
# 317              95.0       0.05
# ...

# %%
df.sort_values(["region", "unidades"], ascending=[True, False])
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 76    2024-01-27  Centro  Javier Sanz   Escritorio  Mobiliario        14
# 83    2024-01-30  Centro   Elena Mora  Auriculares  Accesorios        14
# 162   2024-02-19  Centro   Elena Mora   Monitor 27  Tecnologia        14
# 391   2024-04-30  Centro  Carlos Vega   Silla Ergo  Mobiliario        14
# 446   2024-05-23  Centro   Luis Gomez   Raton Ergo  Accesorios        14
# ...          ...     ...          ...          ...         ...       ...
# 1044  2024-11-09     Sur   Sofia Leon  Teclado Mec  Accesorios         1
# 1079  2024-11-26     Sur   Elena Mora   Tablet Air  Tecnologia         1
# 1094  2024-12-01     Sur   Marta Ruiz   Silla Ergo  Mobiliario         1
# 1104  2024-12-03     Sur   Pedro Diaz   Monitor 27  Tecnologia         1
# 1126  2024-12-08     Sur   Pedro Diaz   Escritorio  Mobiliario         1
#
#       precio_unitario  descuento
# 76              450.0       0.00
# ...

# %%
df.sort_values("unidades", ascending=False).iloc[:5, :]
# Out:
#           fecha  region     vendedor    producto   categoria  unidades  \
# 361  2024-04-22     Sur  Javier Sanz  Tablet Air  Tecnologia        14
# 344  2024-04-18   Norte   Luis Gomez  Laptop Pro  Tecnologia        14
# 76   2024-01-27  Centro  Javier Sanz  Escritorio  Mobiliario        14
# 75   2024-01-26     Sur   Luis Gomez  Escritorio  Mobiliario        14
# 396  2024-05-02     Sur   Pedro Diaz  Silla Ergo  Mobiliario        14
#
#      precio_unitario  descuento
# 361            640.0       0.05
# 344           1200.0       0.00
# 76             450.0       0.00
# 75             450.0       0.00
# 396            280.0       0.10

# %%
df.sort_values("unidades", ascending=False)
# Out:
#           fecha  region     vendedor     producto   categoria  unidades  \
# 361  2024-04-22     Sur  Javier Sanz   Tablet Air  Tecnologia        14
# 344  2024-04-18   Norte   Luis Gomez   Laptop Pro  Tecnologia        14
# 76   2024-01-27  Centro  Javier Sanz   Escritorio  Mobiliario        14
# 75   2024-01-26     Sur   Luis Gomez   Escritorio  Mobiliario        14
# 396  2024-05-02     Sur   Pedro Diaz   Silla Ergo  Mobiliario        14
# ..          ...     ...          ...          ...         ...       ...
# 232  2024-03-07   Norte   Luis Gomez  Auriculares  Accesorios         1
# 224  2024-03-05  Centro   Ana Torres   Raton Ergo  Accesorios         1
# 220  2024-03-04  Centro   Sofia Leon  Teclado Mec  Accesorios         1
# 603  2024-07-05   Norte   Pedro Diaz  Teclado Mec  Accesorios         1
# 983  2024-10-26   Norte   Ana Torres  Teclado Mec  Accesorios         1
#
#      precio_unitario  descuento
# 361            640.0       0.05
# 344           1200.0       0.00
# ...

# %%
df.nlargest(5, ["unidades", "precio_unitario"])
# Out:
#           fecha region    vendedor    producto   categoria  unidades  \
# 340  2024-04-16   Este  Marta Ruiz  Laptop Pro  Tecnologia        14
# 344  2024-04-18  Norte  Luis Gomez  Laptop Pro  Tecnologia        14
# 604  2024-07-05    Sur  Elena Mora  Laptop Pro  Tecnologia        14
# 871  2024-09-25    Sur  Luis Gomez  Laptop Pro  Tecnologia        14
# 952  2024-10-17    Sur  Luis Gomez  Laptop Pro  Tecnologia        14
#
#      precio_unitario  descuento
# 340           1200.0       0.15
# 344           1200.0       0.00
# 604           1200.0       0.00
# 871           1200.0       0.05
# 952           1200.0       0.10

# %%
df.nsmallest(5, ["unidades", "precio_unitario"])
# Out:
#           fecha  region     vendedor    producto   categoria  unidades  \
# 224  2024-03-05  Centro   Ana Torres  Raton Ergo  Accesorios         1
# 248  2024-03-13  Centro  Javier Sanz  Raton Ergo  Accesorios         1
# 249  2024-03-14    Este   Sofia Leon  Raton Ergo  Accesorios         1
# 260  2024-03-19   Norte   Marta Ruiz  Raton Ergo  Accesorios         1
# 276  2024-03-27   Norte   Marta Ruiz  Raton Ergo  Accesorios         1
#
#      precio_unitario  descuento
# 224             45.0        NaN
# 248             45.0       0.00
# 249             45.0       0.00
# 260             45.0       0.00
# 276             45.0       0.05
