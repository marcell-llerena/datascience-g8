# %%
import pandas as pd

ventas = pd.read_csv(
    "/Users/marcell/Documents/codigo_by_tecsup/datascience-g8/data/ventas.csv"
)

ventas["importe"] = ventas["unidades"] * ventas["precio_unitario"]

ventas
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 0     2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 1     2024-01-02     Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 2     2024-01-02  Centro  Carlos Vega   Silla Ergo  Mobiliario         1
# 3     2024-01-02  Centro   Pedro Diaz   Laptop Pro  Tecnologia        10
# 4     2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# ...          ...     ...          ...          ...         ...       ...
# 1195  2024-12-30    Este   Luis Gomez   Raton Ergo  Accesorios         4
# 1196  2024-12-30    Este   Marta Ruiz   Laptop Pro  Tecnologia        13
# 1197  2024-12-31   Oeste   Ana Torres   Monitor 27  Tecnologia         2
# 1198  2024-12-31   Norte   Ana Torres   Monitor 27  Tecnologia         6
# 1199  2024-12-31   Norte   Marta Ruiz   Raton Ergo  Accesorios         8
#
#       precio_unitario  descuento  importe
# 0                 130       0.00      650
# ...

# %%
ventas.groupby("region")["importe"].sum()
# Out:
# region
# Centro    705695
# Este      549745
# Norte     862360
# Oeste     626295
# Sur       699920
# Name: importe, dtype: int64

# %%
ventas[ventas["region"] == "Sur"]["importe"].sum()
# Out:
# np.int64(699920)

# %%
ventas[ventas["region"] == "Sur"]["importe"].mean()
# Out:
# np.float64(2916.3333333333335)

# %%
ventas[ventas["region"] == "Sur"].shape
# Out:
# (240, 9)

# %%
ventas.groupby("region")["importe"].agg(["sum", "mean", "count"])
# Out:
#            sum         mean  count
# region
# Centro  705695  2594.466912    272
# Este    549745  3054.138889    180
# Norte   862360  2827.409836    305
# Oeste   626295  3085.197044    203
# Sur     699920  2916.333333    240

# %%
ventas.groupby("region")["importe"].agg(
    importe_total="sum",
    importe_promedio="mean",
    total_registros="count"
)
# Out:
#         importe_total  importe_promedio  total_registros
# region
# Centro         705695       2594.466912              272
# Este           549745       3054.138889              180
# Norte          862360       2827.409836              305
# Oeste          626295       3085.197044              203
# Sur            699920       2916.333333              240

# %%
ventas.groupby(["region", "categoria"])["importe"].agg(
    importe_total="sum",
    importe_promedio="mean",
    total_registros="count"
)
# Out:
#                    importe_total  importe_promedio  total_registros
# region categoria
# Centro Accesorios          56895        605.265957               94
#        Mobiliario         201520       2651.578947               76
#        Tecnologia         447280       4385.098039              102
# Este   Accesorios          44585        675.530303               66
#        Mobiliario         136520       2730.400000               50
#        Tecnologia         368640       5760.000000               64
# Norte  Accesorios          78630        639.268293              123
#        Mobiliario         200130       2668.400000               75
#        Tecnologia         583600       5454.205607              107
# Oeste  Accesorios          40205        628.203125               64
#        Mobiliario         156170       2692.586207               58
#        Tecnologia         429920       5307.654321               81
# Sur    Accesorios          57800        642.222222               90
# ...

# %%
ventas.groupby("region").agg({
    "importe": ["sum", "mean", "max"],
    "unidades": ["sum"],
    "producto": ["nunique"]
})
# Out:
#        importe                     unidades producto
#            sum         mean    max      sum  nunique
# region
# Centro  705695  2594.466912  15600     1933        8
# Este    549745  3054.138889  16800     1384        8
# Norte   862360  2827.409836  16800     2166        8
# Oeste   626295  3085.197044  15600     1469        8
# Sur     699920  2916.333333  16800     1779        8
