# %% [markdown]
# #### Funciones u operadores en strings
#
# - Longitud de mi cadena (len)
# - Convertir a mayuscula (upper)
# - Convertir a minuscula (lower)
# - Reemplazar un valor de la cadena (replace)
# - "texto      "  -> (strip) -> "texto"
# - "texto1, texto2, texto3" -> (split, ",") -> [texto1, texto2 , texto3]

# %%
nombre = "Marcell"
print("Cuantas letras tiene mi nombre: ", len(nombre))
print(len("peru"))
# Out:
# Cuantas letras tiene mi nombre:  7
# 4

# %%
print(nombre.upper())
# Out:
# MARCELL

# %%
print(nombre.lower())
# Out:
# marcell

# %%
# replace acepta dos parametros, primer parametro: lo que quiero reemplazar, segundo parametro: el valor por el que voy a reemplazar   
print(
    nombre.replace("ll", "lo")
)
# Out:
# Marcelo

# %%
nombre = "Marcell                   "
print(len(nombre)) # 26 caracteres

nombre_limpio = nombre.strip() # limpiando resulta en 7 caracteres

print(len(nombre_limpio))

nombre = "              MARCELL            " # 33 caracteres
print(len(nombre))

nombre_limpio = nombre.strip() # 7 caracteres
print(len(nombre_limpio))
# Out:
# 26
# 7
# 33
# 7

# %%
nombres = "Marcell Llerena"

nombres_separados = nombres.split(" ")
print(nombres_separados)

nombres = "MarcellxxLlerena"
nombres_separados = nombres.split("xx")
print(nombres_separados)
# Out:
# ['Marcell', 'Llerena']
# ['Marcell', 'Llerena']

# %% [markdown]
# ### Indexacion

# %%
nombre = "Peru"

# print(nombre[0])
# print(nombre[1])
# print(nombre[2])
# print(nombre[3])
primera_letra = nombre[0]
print(primera_letra)

ultima_letra = nombre[3]
print(ultima_letra)

ultima_letra_1 = nombre[-1]
print(ultima_letra_1)

# penultima_letra = nombre[2]
# print(penultima_letra)

penultima_letra = nombre[-2]
print(penultima_letra)

segunda_hasta_final = nombre[1:-1]
print(segunda_hasta_final)

segunda_hasta_final = nombre[1:]
print(segunda_hasta_final)

segunda_hasta_final = nombre[1:4]
print(segunda_hasta_final)
# Out:
# P
# u
# u
# r
# er
# eru
# eru

# %%
nombre = "Marcell   "
print(len(nombre))

nombre_limpio = nombre.strip(" ")
print(len(nombre_limpio))

nombre = "Marcellxxx"
nombre_limpio = nombre.strip("x")
print(nombre_limpio)
# Out:
# 10
# 7
# Marcell

# %%
nombre = "Marcell|Llerena|32"
nombre.split("|")
# Out:
# ['Marcell', 'Llerena', '32']
