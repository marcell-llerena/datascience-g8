# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
import plotly.graph_objects as go

# %%
print(plotly.__version__)
# Out:
# 6.9.0

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("iris")
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
# 1. Gráfico de dispersión básico
# Construye un gráfico de dispersión que muestre la relación entre `sepal_length` y `sepal_width`. Diferencia
# cada observación según la especie mediante el parámetro `color`. Agrega un título descriptivo y etiquetas
# claras para ambos ejes.
fig = px.scatter(
    data_frame=df,
    x="sepal_length",
    y="sepal_width",
    color="species",
    title="Longitud vs ancho del sépalo por especie",
    labels={
        "sepal_length": "Longitud del sépalo (cm)",
        "sepal_width": "Ancho del sépalo (cm)",
        "species": "Especie"
    }
)
fig.show()

# %%
# 2. Histograma comparativo por especie
# Representa la distribución de `petal_length` mediante un histograma. Usa 20 bins, diferencia las especies
# con `color`, configura `barmode="overlay"` y aplica una opacidad que permita comparar las distribuciones
# superpuestas.

fig = px.histogram(
    data_frame=df,
    x="petal_length",
    color="species",
    nbins=20,
    barmode="overlay",
    opacity=0.65,
    title="Distribución del largo del pétalo por especie",
    labels={
        "petal_length": "Longitud del pétalo (cm)",
        "species": "Especie"
    }
)

fig.show()

# %%
# 3. Boxplot de ancho del pétalo
# Crea un boxplot de `petal_width` para cada especie. Muestra también los puntos individuales de las
# observaciones. Identifica visualmente qué especie presenta los valores más altos y cuál tiene menor
# dispersión.
fig = px.box(
    data_frame=df,
    x="species",
    y="petal_width",
    color="species",
    points="all",
    title="Ancho del pétalo por especie",
    labels={"specie": "Especie", "petal_width": "Ancho del pétalo (cm)"}
)

fig.show()

# %%
# 4. Violin plot del largo del sépalo
# Construye un gráfico de violín para comparar `sepal_length` entre especies. Incluye dentro del violín un
# boxplot y muestra todos los puntos. Explica qué información adicional aporta el violín respecto al boxplot.

fig = px.violin(
    data_frame=df,
    x="species",
    y="sepal_length",
    color="species",
    points="all",
    box=True,
    title="Distribucion del largo del sépalo por especie",
    labels={
        "species": "Especie",
        "sepal_length": "Longitud del sépalo (cm)"
    }
)

fig.show()

# %%
# 5. Promedio de largo del sépalo por especie
# Calcula el promedio de `sepal_length` por especie con Pandas y visualízalo mediante un gráfico de barras.

promedio_sepalo = (
    df.groupby("species", as_index=False)["sepal_length"].mean()
)
# promedio_sepalo

fig = px.bar(
    promedio_sepalo,
    x="species",
    y="sepal_length",
    text_auto=".3f",
    title="Promedio de longitud del sépalo por especie",
    labels={"species": "Especie", "sepal_length": "Promedio (cm)"}
)

fig.show()

# %%
promedio_sepalo
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %%
# 6. Comparación de promedios de las cuatro medidas
# Calcula, para cada especie, el promedio de `sepal_length`, `sepal_width`, `petal_length` y `petal_width`.
# Crea un gráfico de barras agrupadas que permita comparar las
# cuatro variables entre especies.

promedios = df.groupby("species", as_index=False)[["sepal_length", "sepal_width", "petal_length", "petal_width"]].mean()
promedios

fig = px.bar(
    promedios,
    x="species",
    y=["sepal_length", "sepal_width", "petal_length", "petal_width"],
    barmode="group",
    title="Promedios de las cuatro medidas por especie",
    labels={"species": "Especie", "value": "Promedio (cm)"}
)

fig.show()

# %%
# 7. Scatter multivariable
# Grafica `petal_length` frente a `petal_width`. Usa la especie como `color`, el largo del sépalo como tamaño
# de los puntos (`size`) y la especie también como símbolo (`symbol`). Agrega información adicional al tooltip
# mediante `hover_data`.

fig = px.scatter(
    data_frame=df,
    x="petal_length",
    y="petal_width",
    color="species",
    size="sepal_length",
    symbol="species",
    hover_data=["sepal_width", "species"],
    title="Relación entre medidas del pétalo",
    labels={
        "petal_length": "Longitud del pétalo (cm)",
        "petal_width": "Ancho del pétalo (cm)",
        "sepal_length": "Longitud del sépalo (cm)",
        "species": "Especie",
        "sepal_width": "Ancho del sépalo (cm) xxxxxx"
    }
)

fig.show()

# %%
# 8. Comparación mediante facetas
# Crea un gráfico de dispersión de `sepal_length` frente a `petal_length` y separa cada especie en una faceta
# distinta usando `facet_col`. Mantén una escala comparable para poder observar diferencias entre especies.
fig = px.scatter(
    data_frame=df,
    x="sepal_length",
    y="petal_length",
    facet_col="species",
    color="species",
    title="Longitud del sépalo vs pétalo",
    labels={
        "sepal_length": "Longitud del sépalo (cm)",
        "petal_length": "Longitud del pétalo (cm)",
        "species": "Especie"
    }
)

fig.show()

# %%
# 9. Gráfico de dispersión 3D
# Construye un gráfico 3D usando `sepal_length` en X, `sepal_width` en Y y `petal_length` en Z. Colorea los
# puntos por especie y agrega `petal_width` al tooltip. Explora si las especies forman grupos diferenciables.

fig = px.scatter_3d(
    data_frame=df,
    x="sepal_length",
    y="sepal_width",
    z="petal_length",
    color="species",
    hover_data=["petal_width"],
    title="Grafico scatter 3D"
)
fig.show()

# %%
# Conceptos a practicar: px.violin, densidad, box y puntos.

# Ordena las especies de menor a mayor promedio y muestra el valor promedio sobre cada barra.
# Conceptos a practicar: groupby + px.bar + text_auto.
# Práctica Plotly · Dataset Iris · 15 ejercicios

# Conceptos a practicar: groupby, melt y barras agrupadas.

# Conceptos a practicar: Codificación visual múltiple y hover.

# Conceptos a practicar: facet_col y comparación por paneles.

# Conceptos a practicar: px.scatter_3d e interacción tridimensional.
# 10. Matriz de dispersión
# Crea una matriz de dispersión usando las cuatro variables numéricas y colorea por especie. Oculta la
# diagonal si consideras que mejora la lectura. Determina qué pareja de variables parece separar mejor las
# especies.
# Conceptos a practicar: px.scatter_matrix y análisis multivariable.
# 11. Coordenadas paralelas
# Construye un gráfico de coordenadas paralelas con las cuatro variables numéricas. Utiliza `species_id` para
# colorear las líneas y proporciona etiquetas legibles para las dimensiones. Observa los patrones generales
# de cada especie.
# Conceptos a practicar: px.parallel_coordinates y perfiles multivariables.
# 12. Curvas de densidad por especie
# Usa un gráfico de contornos de densidad para estudiar la relación entre `sepal_length` y `sepal_width`,
# diferenciando por especie. Muestra también los puntos individuales para relacionar las zonas de mayor
# densidad con las observaciones reales.
# Conceptos a practicar: px.density_contour + puntos.
# 13. Dashboard simple con subplots
# Crea una figura 2x2 usando `make_subplots` y `plotly.graph_objects`. Incluye: (1) scatter de largo vs ancho
# del sépalo, (2) histograma de largo del pétalo, (3) boxplot de ancho del pétalo por especie y (4) violin plot
# del largo del sépalo por especie. Añade títulos a cada panel y un título general.
# Conceptos a practicar: make_subplots, graph_objects y composición.
# Práctica Plotly · Dataset Iris · 15 ejercicios
# 14. Gráfico interactivo con menú desplegable
# Crea un histograma interactivo que permita elegir, mediante un menú desplegable (`updatemenus`), cuál de
# las cuatro variables numéricas se desea visualizar. El título y la etiqueta del eje X deben actualizarse al
# cambiar de variable.
# Conceptos a practicar: graph_objects, visibilidad de trazas y updatemenus.
