# %%
import pandas as pd

ventas = pd.read_csv(
    "/Users/marcell/Documents/codigo_by_tecsup/datascience-g8/data/ventas.csv",
    dtype={"precio_unitario": "float64"}
)

# %%
ventas.shape
# Out:
# (1200, 8)

# %%
ventas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fecha            1200 non-null   str
#  1   region           1200 non-null   str
#  2   vendedor         1182 non-null   str
#  3   producto         1200 non-null   str
#  4   categoria        1200 non-null   str
#  5   unidades         1200 non-null   int64
#  6   precio_unitario  1200 non-null   float64
#  7   descuento        1165 non-null   float64
# dtypes: float64(2), int64(1), str(5)
# memory usage: 75.1 KB

# %%
ventas[ ventas["vendedor"].isna() | ventas["descuento"].isna()].shape
# Out:
# (52, 8)

# %%
1200 - 52
# Out:
# 1148

# %%
ventas_sin_nulos = ventas.dropna()
ventas_sin_nulos
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 0     2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 1     2024-01-02     Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 2     2024-01-02  Centro  Carlos Vega   Silla Ergo  Mobiliario         1
# 3     2024-01-02  Centro   Pedro Diaz   Laptop Pro  Tecnologia        10
# 4     2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# ...          ...     ...          ...          ...         ...       ...
# 1195  2024-12-30    Este   Luis Gomez   Raton Ergo  Accesorios         4
# 1196  2024-12-30    Este   Marta Ruiz   Laptop Pro  Tecnologia        13
# 1197  2024-12-31   Oeste   Ana Torres   Monitor 27  Tecnologia         2
# 1198  2024-12-31   Norte   Ana Torres   Monitor 27  Tecnologia         6
# 1199  2024-12-31   Norte   Marta Ruiz   Raton Ergo  Accesorios         8
#
#       precio_unitario  descuento
# 0               130.0       0.00
# ...

# %%
ventas_sin_nulos.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1148 entries, 0 to 1199
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fecha            1148 non-null   str
#  1   region           1148 non-null   str
#  2   vendedor         1148 non-null   str
#  3   producto         1148 non-null   str
#  4   categoria        1148 non-null   str
#  5   unidades         1148 non-null   int64
#  6   precio_unitario  1148 non-null   float64
#  7   descuento        1148 non-null   float64
# dtypes: float64(2), int64(1), str(5)
# memory usage: 80.7 KB

# %%
1200 - 18
# Out:
# 1182

# %%
ventas[ ventas["vendedor"].isna() ]
# Out:
#            fecha  region vendedor    producto   categoria  unidades  \
# 79    2024-01-29   Oeste      NaN  Raton Ergo  Accesorios        14
# 161   2024-02-18   Oeste      NaN  Silla Ergo  Mobiliario         1
# 203   2024-02-28   Norte      NaN  Raton Ergo  Accesorios         4
# 456   2024-05-28   Oeste      NaN  Tablet Air  Tecnologia         5
# 549   2024-06-20   Oeste      NaN  Raton Ergo  Accesorios        14
# 553   2024-06-22   Norte      NaN  Raton Ergo  Accesorios         7
# 571   2024-06-28    Este      NaN  Laptop Pro  Tecnologia        13
# 577   2024-06-29    Este      NaN  Tablet Air  Tecnologia         8
# 639   2024-07-16   Norte      NaN  Raton Ergo  Accesorios         5
# 660   2024-07-21     Sur      NaN  Monitor 27  Tecnologia        14
# 746   2024-08-18  Centro      NaN  Escritorio  Mobiliario        13
# 758   2024-08-20  Centro      NaN  Silla Ergo  Mobiliario        14
# 781   2024-08-28   Norte      NaN  Laptop Pro  Tecnologia         5
# ...

# %%
ventas_sin_nulos_por_columna = ventas.dropna(subset="vendedor")
ventas_sin_nulos_por_columna
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 0     2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 1     2024-01-02     Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 2     2024-01-02  Centro  Carlos Vega   Silla Ergo  Mobiliario         1
# 3     2024-01-02  Centro   Pedro Diaz   Laptop Pro  Tecnologia        10
# 4     2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# ...          ...     ...          ...          ...         ...       ...
# 1195  2024-12-30    Este   Luis Gomez   Raton Ergo  Accesorios         4
# 1196  2024-12-30    Este   Marta Ruiz   Laptop Pro  Tecnologia        13
# 1197  2024-12-31   Oeste   Ana Torres   Monitor 27  Tecnologia         2
# 1198  2024-12-31   Norte   Ana Torres   Monitor 27  Tecnologia         6
# 1199  2024-12-31   Norte   Marta Ruiz   Raton Ergo  Accesorios         8
#
#       precio_unitario  descuento
# 0               130.0       0.00
# ...

# %%
ventas.dropna(axis=1)
# Out:
#            fecha  region     producto   categoria  unidades  precio_unitario
# 0     2024-01-02   Oeste  Auriculares  Accesorios         5            130.0
# 1     2024-01-02     Sur   Monitor 27  Tecnologia        14            320.0
# 2     2024-01-02  Centro   Silla Ergo  Mobiliario         1            280.0
# 3     2024-01-02  Centro   Laptop Pro  Tecnologia        10           1200.0
# 4     2024-01-03     Sur  Auriculares  Accesorios         2            130.0
# ...          ...     ...          ...         ...       ...              ...
# 1195  2024-12-30    Este   Raton Ergo  Accesorios         4             45.0
# 1196  2024-12-30    Este   Laptop Pro  Tecnologia        13           1200.0
# 1197  2024-12-31   Oeste   Monitor 27  Tecnologia         2            320.0
# 1198  2024-12-31   Norte   Monitor 27  Tecnologia         6            320.0
# 1199  2024-12-31   Norte   Raton Ergo  Accesorios         8             45.0
#
# [1200 rows x 6 columns]

# %%
ventas.dropna(thresh=2)
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 0     2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 1     2024-01-02     Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 2     2024-01-02  Centro  Carlos Vega   Silla Ergo  Mobiliario         1
# 3     2024-01-02  Centro   Pedro Diaz   Laptop Pro  Tecnologia        10
# 4     2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# ...          ...     ...          ...          ...         ...       ...
# 1195  2024-12-30    Este   Luis Gomez   Raton Ergo  Accesorios         4
# 1196  2024-12-30    Este   Marta Ruiz   Laptop Pro  Tecnologia        13
# 1197  2024-12-31   Oeste   Ana Torres   Monitor 27  Tecnologia         2
# 1198  2024-12-31   Norte   Ana Torres   Monitor 27  Tecnologia         6
# 1199  2024-12-31   Norte   Marta Ruiz   Raton Ergo  Accesorios         8
#
#       precio_unitario  descuento
# 0               130.0       0.00
# ...

# %%
import numpy as np

df = pd.DataFrame(
{
"name": ["Alfred", "Batman", "Catwoman"],
"toy": [np.nan, "Batmobile", "Bullwhip"],
"born": [pd.NaT, pd.Timestamp("1940-04-25"), pd.NaT],
}
 )
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(thresh=2)
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
ventas[ ventas["descuento"].isna() ]
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 33    2024-01-11     Sur  Javier Sanz   Laptop Pro  Tecnologia         5
# 72    2024-01-25   Oeste   Ana Torres  Teclado Mec  Accesorios        12
# 78    2024-01-28     Sur   Pedro Diaz   Tablet Air  Tecnologia         3
# 82    2024-01-30   Oeste   Pedro Diaz   Laptop Pro  Tecnologia         7
# 98    2024-02-03  Centro   Ana Torres   Monitor 27  Tecnologia         1
# 102   2024-02-03   Norte   Ana Torres   Raton Ergo  Accesorios        11
# 109   2024-02-04    Este   Ana Torres   Raton Ergo  Accesorios        12
# 123   2024-02-09    Este   Sofia Leon   Silla Ergo  Mobiliario        14
# 135   2024-02-13    Este   Marta Ruiz   Laptop Pro  Tecnologia         8
# 222   2024-03-04  Centro   Marta Ruiz   Laptop Pro  Tecnologia        12
# 224   2024-03-05  Centro   Ana Torres   Raton Ergo  Accesorios         1
# 239   2024-03-11    Este  Javier Sanz   Escritorio  Mobiliario         3
# ...

# %%
promedio = ventas["descuento"].mean()
promedio
# Out:
# np.float64(0.04763948497854077)

# %%
ventas["descuento"].unique()
# Out:
# array([0.  , 0.1 , 0.05, 0.15,  nan])

# %%
ventas["descuento"] = ventas["descuento"].fillna(promedio)

# %%
ventas["descuento"].unique()
# Out:
# array([0.        , 0.1       , 0.05      , 0.15      , 0.04763948])

# %%
ventas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fecha            1200 non-null   str
#  1   region           1200 non-null   str
#  2   vendedor         1182 non-null   str
#  3   producto         1200 non-null   str
#  4   categoria        1200 non-null   str
#  5   unidades         1200 non-null   int64
#  6   precio_unitario  1200 non-null   float64
#  7   descuento        1200 non-null   float64
# dtypes: float64(2), int64(1), str(5)
# memory usage: 75.1 KB

# %%
ventas[ventas["vendedor"].isna()]
# Out:
#            fecha  region vendedor    producto   categoria  unidades  \
# 79    2024-01-29   Oeste      NaN  Raton Ergo  Accesorios        14
# 161   2024-02-18   Oeste      NaN  Silla Ergo  Mobiliario         1
# 203   2024-02-28   Norte      NaN  Raton Ergo  Accesorios         4
# 456   2024-05-28   Oeste      NaN  Tablet Air  Tecnologia         5
# 549   2024-06-20   Oeste      NaN  Raton Ergo  Accesorios        14
# 553   2024-06-22   Norte      NaN  Raton Ergo  Accesorios         7
# 571   2024-06-28    Este      NaN  Laptop Pro  Tecnologia        13
# 577   2024-06-29    Este      NaN  Tablet Air  Tecnologia         8
# 639   2024-07-16   Norte      NaN  Raton Ergo  Accesorios         5
# 660   2024-07-21     Sur      NaN  Monitor 27  Tecnologia        14
# 746   2024-08-18  Centro      NaN  Escritorio  Mobiliario        13
# 758   2024-08-20  Centro      NaN  Silla Ergo  Mobiliario        14
# 781   2024-08-28   Norte      NaN  Laptop Pro  Tecnologia         5
# ...

# %%
ventas["vendedor"].value_counts()
# Out:
# vendedor
# Marta Ruiz     170
# Ana Torres     165
# Sofia Leon     156
# Pedro Diaz     150
# Elena Mora     137
# Javier Sanz    137
# Luis Gomez     135
# Carlos Vega    132
# Name: count, dtype: int64

# %%
ventas["vendedor"] = ventas["vendedor"].fillna("Marta Ruiz")

# %%
ventas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fecha            1200 non-null   str
#  1   region           1200 non-null   str
#  2   vendedor         1200 non-null   str
#  3   producto         1200 non-null   str
#  4   categoria        1200 non-null   str
#  5   unidades         1200 non-null   int64
#  6   precio_unitario  1200 non-null   float64
#  7   descuento        1200 non-null   float64
# dtypes: float64(2), int64(1), str(5)
# memory usage: 75.1 KB

# %%
ventas["vendedor"].value_counts()
# Out:
# vendedor
# Marta Ruiz     188
# Ana Torres     165
# Sofia Leon     156
# Pedro Diaz     150
# Elena Mora     137
# Javier Sanz    137
# Luis Gomez     135
# Carlos Vega    132
# Name: count, dtype: int64

# %%
ventas["vendedor"].value_counts()
# Out:
# vendedor
# Marta Ruiz     188
# Ana Torres     165
# Sofia Leon     156
# Pedro Diaz     150
# Elena Mora     137
# Javier Sanz    137
# Luis Gomez     135
# Carlos Vega    132
# Name: count, dtype: int64

# %%
ventas = pd.read_csv(
    "/Users/marcell/Documents/codigo_by_tecsup/datascience-g8/data/ventas.csv",
    dtype={"precio_unitario": "float64"}
)

# Calcula el porcentaje de nulos por columna en ventas.csv.
ventas.isna().mean() * 100
# Out:
# fecha              0.000000
# region             0.000000
# vendedor           1.500000
# producto           0.000000
# categoria          0.000000
# unidades           0.000000
# precio_unitario    0.000000
# descuento          2.916667
# dtype: float64

# %%
# Rellena descuento con 0 y justifica en un comentario por qué es razonable.
ventas["descuento"] = ventas["descuento"].fillna(0)

# %%
ventas["descuento"].value_counts()
# Out:
# descuento
# 0.00    626
# 0.05    213
# 0.10    186
# 0.15    175
# Name: count, dtype: int64

# %%
ventas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fecha            1200 non-null   str
#  1   region           1200 non-null   str
#  2   vendedor         1182 non-null   str
#  3   producto         1200 non-null   str
#  4   categoria        1200 non-null   str
#  5   unidades         1200 non-null   int64
#  6   precio_unitario  1200 non-null   float64
#  7   descuento        1200 non-null   float64
# dtypes: float64(2), int64(1), str(5)
# memory usage: 75.1 KB

# %%
# Rellena vendedor con 'Sin asignar' sin perder ninguna fila.
ventas.fillna({"vendedor": "Sin asignar"}, inplace=True) # ventas["vendedor"] = ventas["vendedor"].fillna("Sin asignar")
# ventas.info()

# En empleados, rellena la nota vacía con la mediana de la columna.
empleados = pd.read_csv("/Users/marcell/Documents/codigo_by_tecsup/datascience-g8/data/empleados.csv")

mediana = empleados["evaluacion"].median()
empleados["evaluacion"] = empleados["evaluacion"].fillna(mediana )

# Crea una copia de empleados eliminando las filas sin nota y compara cuántas filas pierdes.
emp_copy = empleados.copy()
emp_sin_nota = empleados.dropna(subset="evaluacion")

# Comprueba con isna().sum() que ya no queda ningún nulo.
emp_sin_nota["evaluacion"].isna().sum()
# Out:
# np.int64(0)
